# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread('car.jpg')
plt.imshow(img)

# %%
plt.imshow(img)
# plt.xticks([])
# plt.yticks([])
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(5183.5), np.float64(3455.5), np.float64(-0.5))

# %%
a,b,c=img.shape[:3]
print(a,b,c)
# Out:
# 3456 5184 3

# %%
img=cv2.imread('car.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('car.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.array([[-1,-1,-1,],[-1,8,1],[-1,-1,-1]])
k1output=cv2.filter2D(img,-1,k1)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(k1output),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x15f9768abd0>,
#  (np.float64(-0.5), np.float64(5183.5), np.float64(3455.5), np.float64(-0.5)))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img=cv2.imread('car.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
k1=np.ones((6,6),np.float64)/36
k1output=cv2.filter2D(img,-1,k1)
plt.subplot(1,2,1),plt.imshow(img),plt.axis('off')
plt.subplot(1,2,2),plt.imshow(k1output),plt.axis('off')
# Out:
# (<Axes: >,
#  <matplotlib.image.AxesImage at 0x15fb66e22d0>,
#  (np.float64(-0.5), np.float64(5183.5), np.float64(3455.5), np.float64(-0.5)))

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img=cv2.imread('car.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#box blur
box=cv2.blur(img,(75,75))

#gausian blur
gaus=cv2.GaussianBlur(img,(95,95),0)

#median blur
med=cv2.medianBlur(img,75)

plt.subplot(2,2,1),plt.imshow(img),plt.title('source title')
plt.subplot(2,2,2),plt.imshow(box),plt.title('box blur image ')
plt.subplot(2,2,3),plt.imshow(gaus),plt.title('gaussian blur title')
plt.subplot(2,2,4),plt.imshow(med),plt.title('median blur title')
# Out:
# (<Axes: title={'center': 'median blur title'}>,
#  <matplotlib.image.AxesImage at 0x1e70b527ad0>,
#  Text(0.5, 1.0, 'median blur title'))
